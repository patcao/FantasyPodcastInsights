# %%
# %load_ext autoreload
# %autoreload 2

import os
import re
import sys

sys.path.append(os.path.abspath("../"))


import faiss
import numpy as np
import pandas as pd
from dotenv import load_dotenv
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter

pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 1000)
pd.set_option("display.max_rows", 400)


load_dotenv()


from src.data_utils import PodcastContainer, load_clean_scores
from src.player_utils import PlayerUtil
from src.utils import get_repo_root

scores = load_clean_scores(["2022-23", "2023-24"])
scores.head(5)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#        season_year  game_date    gameId      matchup teamName teamSlug  personId     personName    minutes  fieldGoalsMade  fieldGoalsAttempted  fieldGoalsPercentage  threePointersMade  threePointersAttempted  threePointersPercentage  freeThrowsMade  freeThrowsAttempted  freeThrowsPercentage  reboundsOffensive  reboundsDefensive  reboundsTotal  assists  steals  blocks  turnovers  foulsPersonal  points  plusMinusPoints  fantasyPoints  projectedFantasyPoints  outperformed
# 360551     2022-23 2022-10-18  22200001    PHI @ BOS    76ers   sixers    200782      pj tucker  33.016667               3                    5                 0.600                  0                       2                    0.000               0                    0                   0.0                  2                  2              4        0       0       1          2              2       6               -6          12.00                   17.15         False
# 360552     2022-23 2022-10-18  22200001  BOS vs. PHI  celtics  celtics    201143     al horford  23.100000               2                    7                 0.286                  2                       5                    0.400               0                    0                   0.0                  1                  4              5        1       0       0          0              4       6                8          13.75                   35.15         False
# 360553     2022-23 2022-10-18  22200001  BOS vs. PHI  celtics  celtics    201933  blake griffin   8.283333               0                    2                 0.000                  0                       1                    0.000               1                    2                   0.5                  2                  3              5        1       0       0          0              3       1               -5           8.75                    0.50          True
# 360554     2022-23 2022-10-18  22200001    PHI @ BOS    76ers   sixers    201935   james harden  37.266667               9                   14                 0.643                  5                       9                    0.556              12                   12                   1.0                  0                  8              8        7       0       0          3              3      35                1          54.00                   44.05          True
# 360555     2022-23 2022-10-18  22200001    PHI @ BOS    76ers   sixers    202699  tobias harris  34.233333               7                   14                 0.500                  3                       6                    0.500               1                    2                   0.5                  1                  1              2        0       3       0          0              3      18               -1          26.50                   25.95          True

# %%
scores.game_date.unique()
# Out:
# <DatetimeArray>
# ['2023-10-24 00:00:00', '2023-10-25 00:00:00', '2023-10-26 00:00:00', '2023-10-27 00:00:00', '2023-10-28 00:00:00', '2023-10-29 00:00:00', '2023-10-30 00:00:00', '2023-10-31 00:00:00', '2023-11-01 00:00:00', '2023-11-02 00:00:00',
#  ...
#  '2024-04-03 00:00:00', '2024-04-04 00:00:00', '2024-04-05 00:00:00', '2024-04-06 00:00:00', '2024-04-07 00:00:00', '2024-04-09 00:00:00', '2024-04-10 00:00:00', '2024-04-11 00:00:00', '2024-04-12 00:00:00', '2024-04-14 00:00:00']
# Length: 160, dtype: datetime64[ns]

# %%
from src.llm_feature_extractor import PromptFeatureExtractor

prompt_fe = PromptFeatureExtractor()
cont = PodcastContainer(
    {
        "rotowire": get_repo_root() / "data/raw/DG RFB Transcripts/",
    }
)

# cont = PodcastContainer()
podcast_df = cont.get_all_episodes()
begin, end = pd.to_datetime("2023-10-22").date(), pd.to_datetime("2023-10-26").date()

podcast_df = podcast_df[
    (podcast_df.publication_date >= begin) & (podcast_df.publication_date < end)
]
podcast_df
# Out:
#   publication_date                                          file_name                                          file_path                                            content  duration podcast_name
# 3       2023-10-23  western_conference_win_total_overunder_picks_w...  G:\My Drive\Columbia\Practical Deep Learning\F...  Welcome to the rotor wire fantasy basketball p...      4359     rotowire
# 4       2023-10-24  opening_week_preview_boom_or_bust_players_thre...  G:\My Drive\Columbia\Practical Deep Learning\F...  Hello, friends, and welcome to the award winni...      2664     rotowire
# 5       2023-10-25  opening_night_takeaways_lebrons_workload_harde...  G:\My Drive\Columbia\Practical Deep Learning\F...  Welcome to a regular season edition, Brandon K...      3264     rotowire

# %%
# podcast_df = cont.get_all_episodes()
# podcast_df = podcast_df[podcast_df.publication_date == pd.to_datetime('2023-10-24').date()]
# podcast_df
# Out:
#   publication_date                                          file_name                                          file_path                                            content  duration podcast_name
# 4       2023-10-24  opening_week_preview_boom_or_bust_players_thre...  G:\My Drive\Columbia\Practical Deep Learning\F...  Hello, friends, and welcome to the award winni...      2664     rotowire

# %%
# llm_feats2 = prompt_fe.extract_llm_feats(podcast_df)

# %%
llm_feats = prompt_fe.extract_llm_feats(podcast_df)

# %%
feats = llm_feats.groupby(['podcast_name', 'personName', 'podcast_date']).agg({
    'mentions': 'sum',
    'increased_playing_time': 'mean',
    'trending_upwards': 'mean'
}).reset_index()

# %%
# TODO join feats with the box score dataframe

# TODO compute AOC with just the trending_upwards column


# Train XGBOOST model

# %%
from sklearn.model_selection import train_test_split
from src.model_xg import add_lagged_features
from xgboost import XGBRegressor

lag_features = [
    "minutes",
    "fieldGoalsAttempted",
    "fieldGoalsPercentage",
    "threePointersAttempted",
    "threePointersPercentage",
    "freeThrowsAttempted",
    "freeThrowsPercentage",
    "reboundsDefensive",
    "reboundsTotal",
    "assists",
    "steals",
    "blocks",
    "turnovers",
    "foulsPersonal",
    "points",
]

df_xg, new_feats = add_lagged_features(scores, lag_features, 5)
df_xg = df_xg.dropna()

# ---- Create train/test dataset ----
select_features = ["plusMinusPoints"] + new_feats
target_col = "fantasyPoints"

train_size = int(len(df) * 0.8)
train_df = df_xg.iloc[train_size:]
test_df = df_xg.iloc[:train_size]

X_train, X_test = train_df[select_features], test_df[select_features]
y_train, y_test = train_df[target_col], test_df[target_col]

# ---- Train XGBoost model ----
model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42)
model.fit(X_train, y_train)

# ---- Evaluate the model ----
y_pred = model.predict(X_test)

display(df_xg)

# 5-day moving average performance
print(
    "Sliding Window MAE:", np.mean(np.abs(y_test - test_df["projectedFantasyPoints"]))
)
print("Model MAE:", np.mean(np.abs(y_test - y_pred)))

# %%
----

# %%
from typing import List

from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel

system_prompt = """You are a specialized NBA analyst. Analyze the following text for NBA player mentions, including pronouns and nicknames. Provide a precise, structured analysis.

Requirements:
1. Identify all NBA players active in the 2023 season mentioned. 
2. Do not use player nicknames in the output, use their real names instead.
3. Count total mentions for each player
4. Analyze whether a player is likely to see increased playing time in upcoming games
5. Analyze whether a player is likely to outperform or trending upwards in upcoming games


Return the results as a CSV with the header:
player, mentions, increased_playing_time, trending_upwards

Context:
{}
"""

llm = ChatOpenAI(temperature=0)

response = llm.invoke(system_prompt.format(podcast_text))

# %%
from io import StringIO

import pandas as pd
from src.player_utils import normalize_name

df = pd.read_csv(StringIO(response.content))

df["player"] = df["player"].apply(normalize_name)
df["increased_playing_time"] = np.where(
    df["increased_playing_time"].str.lower() == "yes", 1, 0
)
df["trending_upwards"] = np.where(df["trending_upwards"].str.lower() == "yes", 1, 0)
df["podcast_date"] = pd.to_datetime(pd.to_datetime(pub_date).date())

df.head(20)
# Out:
#                player  mentions  increased_playing_time  trending_upwards  \
# 0      damian lillard         3                       0                 1
# 1        tyrese maxey         1                       1                 1
# 2         kelly oubre         1                       0                 0
# 3        james harden         6                       0                 0
# 4         joel embiid         4                       0                 0
# 5       anthony davis         3                       1                 1
# 6        miles turner         2                       1                 1
# 7      brandon miller         1                       0                 0
# 8      xavier tillman         3                       1                 1
# 9        santi aldama         1                       0                 0
# 10       derek lively         4                       1                 1
# 11         cam thomas         4                       1                 1
# 12         isaiah joe         2                       1                 1
# 13        josh okogie         1                       1                 1
# 14         chris paul         2                       1                 1
# 15    cade cunningham         2                       1                 1
# 16        jalen duran         2                       1                 1
# 17     andre drummond         2                       1                 1
# 18  victor wim biyana         1                       0                 0
# 19      chet holmgren         4                       0                 0
#
#    podcast_date
# 0    2023-10-27
# 1    2023-10-27
# 2    2023-10-27
# 3    2023-10-27
# 4    2023-10-27
# 5    2023-10-27
# 6    2023-10-27
# 7    2023-10-27
# 8    2023-10-27
# 9    2023-10-27
# 10   2023-10-27
# 11   2023-10-27
# 12   2023-10-27
# 13   2023-10-27
# 14   2023-10-27
# 15   2023-10-27
# 16   2023-10-27
# 17   2023-10-27
# 18   2023-10-27
# 19   2023-10-27

# %%
scores.game_date.unique()
# Out:
# <DatetimeArray>
# ['2023-10-24 00:00:00', '2023-10-25 00:00:00', '2023-10-26 00:00:00',
#  '2023-10-27 00:00:00', '2023-10-28 00:00:00', '2023-10-29 00:00:00',
#  '2023-10-30 00:00:00', '2023-10-31 00:00:00', '2023-11-01 00:00:00',
#  '2023-11-02 00:00:00',
#  ...
#  '2024-04-03 00:00:00', '2024-04-04 00:00:00', '2024-04-05 00:00:00',
#  '2024-04-06 00:00:00', '2024-04-07 00:00:00', '2024-04-09 00:00:00',
#  '2024-04-10 00:00:00', '2024-04-11 00:00:00', '2024-04-12 00:00:00',
#  '2024-04-14 00:00:00']
# Length: 160, dtype: datetime64[ns]

# %%
pub_date
# Out:
# datetime.date(2023, 10, 27)

# %%
s = scores[(scores.game_date >= "2023-10-27") & (scores.game_date <= "2023-10-31")]

# set(s.personName) & set(df.player.str.lower())
s.game_date
# Out:
# 392548   2023-10-27
# 392549   2023-10-27
# 392550   2023-10-27
# 392551   2023-10-27
# 392552   2023-10-27
#             ...
# 393603   2023-10-31
# 393604   2023-10-31
# 393605   2023-10-31
# 393606   2023-10-31
# 393607   2023-10-31
# Name: game_date, Length: 1060, dtype: datetime64[ns]

# %%
df.podcast_date
# Out:
# 0     2023-10-27
# 1     2023-10-27
# 2     2023-10-27
# 3     2023-10-27
# 4     2023-10-27
#          ...
# 168   2023-10-27
# 169   2023-10-27
# 170   2023-10-27
# 171   2023-10-27
# 172   2023-10-27
# Name: podcast_date, Length: 173, dtype: datetime64[ns]

# %%
m = pd.merge_asof(
    s,
    df,
    left_on="game_date",
    right_on="podcast_date",
    left_by="personName",
    right_by="player",
    tolerance=pd.Timedelta("5d"),
)
m
# Out:
#      season_year  game_date    gameId      matchup  teamName  teamSlug  \
# 0        2023-24 2023-10-27  22300077  CHA vs. DET   hornets   hornets
# 1        2023-24 2023-10-27  22300077    DET @ CHA   pistons   pistons
# 2        2023-24 2023-10-27  22300077    DET @ CHA   pistons   pistons
# 3        2023-24 2023-10-27  22300077  CHA vs. DET   hornets   hornets
# 4        2023-24 2023-10-27  22300077  CHA vs. DET   hornets   hornets
# ...          ...        ...       ...          ...       ...       ...
# 1055     2023-24 2023-10-31  22300114  LAC vs. ORL  clippers  clippers
# 1056     2023-24 2023-10-31  22300114    ORL @ LAC     magic     magic
# 1057     2023-24 2023-10-31  22300114    ORL @ LAC     magic     magic
# 1058     2023-24 2023-10-31  22300114  LAC vs. ORL  clippers  clippers
# 1059     2023-24 2023-10-31  22300114  LAC vs. ORL  clippers  clippers
#
#       personId       personName    minutes  fieldGoalsMade  ...  points  \
# 0       202330   gordon hayward  33.866667               6  ...      19
# 1       202692       alec burks  30.750000               5  ...      24
# 2       203925       joe harris  11.316667               1  ...       2
# 3      1626179     terry rozier  34.700000               8  ...      20
# 4      1628373  frank ntilikina   0.000000               0  ...       0
# ...        ...              ...        ...             ...  ...     ...
# 1055   1631217   moussa diabate   2.916667               1  ...       2
# 1056   1641710    anthony black   3.933333               0  ...       0
# 1057   1641724      jett howard   3.933333               1  ...       2
# 1058   1641738       kobe brown  19.033333               3  ...       7
# 1059   1641757    jordan miller   2.916667               1  ...       3
#
#       plusMinusPoints  fantasyPoints  projectedFantasyPoints  outperformed  \
# 0                 -10          40.75               33.550000          True
# 1                  28          36.00               20.650000          True
# 2                   3           5.50                7.950000         False
# 3                 -11          26.25               24.200000          True
# 4                   0           0.00               11.100000         False
# ...               ...            ...                     ...           ...
# 1055                2           5.75                2.850000          True
# 1056               -1           1.50                3.500000         False
# 1057               -1           3.25                0.500000          True
# 1058               11          14.25                3.833333          True
# 1059                2           3.00                0.666667          True
#
#       player  mentions  increased_playing_time  trending_upwards  podcast_date
# 0        NaN       NaN                     NaN               NaN           NaT
# 1        NaN       NaN                     NaN               NaN           NaT
# 2        NaN       NaN                     NaN               NaN           NaT
# 3        NaN       NaN                     NaN               NaN           NaT
# 4        NaN       NaN                     NaN               NaN           NaT
# ...      ...       ...                     ...               ...           ...
# 1055     NaN       NaN                     NaN               NaN           NaT
# 1056     NaN       NaN                     NaN               NaN           NaT
# 1057     NaN       NaN                     NaN               NaN           NaT
# 1058     NaN       NaN                     NaN               NaN           NaT
# 1059     NaN       NaN                     NaN               NaN           NaT
#
# [1060 rows x 36 columns]

# %%
m[m.game_date == "2023-10-27"].head(40)
# Out:
#    season_year  game_date    gameId      matchup   teamName   teamSlug  \
# 0      2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 1      2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 2      2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 3      2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 4      2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 5      2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 6      2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 7      2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 8      2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 9      2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 10     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 11     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 12     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 13     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 14     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 15     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 16     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 17     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 18     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 19     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 20     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 21     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 22     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 23     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 24     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 25     2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 26     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 27     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 28     2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 29     2023-24 2023-10-27  22300078  MEM vs. DEN  grizzlies  grizzlies
# 30     2023-24 2023-10-27  22300078    DEN @ MEM    nuggets    nuggets
# 31     2023-24 2023-10-27  22300078    DEN @ MEM    nuggets    nuggets
# 32     2023-24 2023-10-27  22300078    DEN @ MEM    nuggets    nuggets
# 33     2023-24 2023-10-27  22300078    DEN @ MEM    nuggets    nuggets
# 34     2023-24 2023-10-27  22300078    DEN @ MEM    nuggets    nuggets
# 35     2023-24 2023-10-27  22300078  MEM vs. DEN  grizzlies  grizzlies
# 36     2023-24 2023-10-27  22300078    DEN @ MEM    nuggets    nuggets
# 37     2023-24 2023-10-27  22300078    DEN @ MEM    nuggets    nuggets
# 38     2023-24 2023-10-27  22300078  MEM vs. DEN  grizzlies  grizzlies
# 39     2023-24 2023-10-27  22300078    DEN @ MEM    nuggets    nuggets
#
#     personId                personName    minutes  fieldGoalsMade  ...  \
# 0     202330            gordon hayward  33.866667               6  ...
# 1     202692                alec burks  30.750000               5  ...
# 2     203925                joe harris  11.316667               1  ...
# 3    1626179              terry rozier  34.700000               8  ...
# 4    1628373           frank ntilikina   0.000000               0  ...
# 5    1628963         marvin bagley iii  13.150000               5  ...
# 6    1628970             miles bridges   0.000000               0  ...
# 7    1629023             pj washington  28.983333               6  ...
# 8    1630163               lamelo ball  33.066667               4  ...
# 9    1630164             james wiseman   0.000000               0  ...
# 10   1630165             killian hayes  29.433333               2  ...
# 11   1630177              theo maledon  14.133333               1  ...
# 12   1630191            isaiah stewart  36.216667               6  ...
# 13   1630208             nick richards  16.316667               0  ...
# 14   1630550                   jt thor  24.816667               1  ...
# 15   1630595           cade cunningham  24.133333               4  ...
# 16   1630608           malcolm cazalon   0.000000               0  ...
# 17   1630649             stanley umude   0.000000               0  ...
# 18   1631093                jaden ivey  23.000000               8  ...
# 19   1631105               jalen duren  34.850000               7  ...
# 20   1631109             mark williams  20.700000               1  ...
# 21   1631121            bryce mcgowens   0.000000               0  ...
# 22   1631197              jared rhoden   0.000000               0  ...
# 23   1631204             marcus sasser   7.566667               0  ...
# 24   1641706            brandon miller  33.416667               6  ...
# 25   1641709            ausar thompson  29.583333               2  ...
# 26   1641733             nick smith jr   0.000000               0  ...
# 27   1641735              amari bailey   0.000000               0  ...
# 28   1641778               leaky black   0.000000               0  ...
# 29    201565              derrick rose  21.900000               6  ...
# 30    201599            deandre jordan   0.000000               0  ...
# 31    202704            reggie jackson  21.700000               7  ...
# 32    203200            justin holiday   0.000000               0  ...
# 33    203484  kentavious caldwell-pope  34.966667               3  ...
# 34    203932              aaron gordon  30.333333               5  ...
# 35    203935              marcus smart  30.833333               7  ...
# 36    203999              nikola jokic  34.966667               8  ...
# 37   1627750              jamal murray  33.900000               7  ...
# 38   1628991          jaren jackson jr  28.450000               9  ...
# 39   1629008         michael porter jr  28.866667               3  ...
#
#     points  plusMinusPoints  fantasyPoints  projectedFantasyPoints  \
# 0       19              -10          40.75                   33.55
# 1       24               28          36.00                   20.65
# 2        2                3           5.50                    7.95
# 3       20              -11          26.25                   24.20
# 4        0                0           0.00                   11.10
# 5       14                6          20.50                   13.70
# 6        0                0           0.00                   30.55
# 7       13              -12          26.25                   39.55
# 8       20               -7          48.75                   47.65
# 9        0                0           0.00                   16.30
# 10       6               -7          18.75                   31.90
# 11       6               -2          12.00                   35.10
# 12      15                6          25.25                   16.25
# 13       0                1           7.50                   19.70
# 14       2                0          11.00                   16.00
# 15      12                7          23.00                   33.70
# 16       0                0           0.00                    0.00
# 17       0                0           0.00                    1.50
# 18      18               -2          27.50                   34.05
# 19      14                6          44.75                   35.40
# 20       2              -17           8.75                   29.50
# 21       0                0           0.00                   24.70
# 22       0                0           0.00                    9.20
# 23       0                3           2.25                   11.50
# 24      17               -2          30.00                   19.25
# 25       6               10          31.75                   26.25
# 26       0                0           0.00                    0.00
# 27       0                0           0.00                    0.00
# 28       0                0           0.00                    0.00
# 29      16               -1          26.00                    3.00
# 30       0                0           0.00                   11.60
# 31      16               -4          27.50                   21.20
# 32       0                0           0.00                    7.60
# 33       8                6          24.00                   20.95
# 34      10                8          24.50                   37.70
# 35      20               -6          39.00                   25.60
# 36      22                6          48.50                   54.90
# 37      22                8          31.25                   32.55
# 38      21               -1          41.25                   43.15
# 39       9                4          29.25                   27.20
#
#     outperformed           player  mentions  increased_playing_time  \
# 0           True              NaN       NaN                     NaN
# 1           True              NaN       NaN                     NaN
# 2          False              NaN       NaN                     NaN
# 3           True              NaN       NaN                     NaN
# 4          False              NaN       NaN                     NaN
# 5           True              NaN       NaN                     NaN
# 6          False              NaN       NaN                     NaN
# 7          False              NaN       NaN                     NaN
# 8           True              NaN       NaN                     NaN
# 9          False              NaN       NaN                     NaN
# 10         False              NaN       NaN                     NaN
# 11         False              NaN       NaN                     NaN
# 12          True              NaN       NaN                     NaN
# 13         False              NaN       NaN                     NaN
# 14         False              NaN       NaN                     NaN
# 15         False  cade cunningham       2.0                     1.0
# 16         False              NaN       NaN                     NaN
# 17         False              NaN       NaN                     NaN
# 18         False              NaN       NaN                     NaN
# 19          True              NaN       NaN                     NaN
# 20         False              NaN       NaN                     NaN
# 21         False              NaN       NaN                     NaN
# 22         False              NaN       NaN                     NaN
# 23         False              NaN       NaN                     NaN
# 24          True   brandon miller       1.0                     0.0
# 25          True              NaN       NaN                     NaN
# 26         False              NaN       NaN                     NaN
# 27         False              NaN       NaN                     NaN
# 28         False              NaN       NaN                     NaN
# 29          True              NaN       NaN                     NaN
# 30         False              NaN       NaN                     NaN
# 31          True              NaN       NaN                     NaN
# 32         False              NaN       NaN                     NaN
# 33          True              NaN       NaN                     NaN
# 34         False              NaN       NaN                     NaN
# 35          True              NaN       NaN                     NaN
# 36         False              NaN       NaN                     NaN
# 37         False              NaN       NaN                     NaN
# 38         False              NaN       NaN                     NaN
# 39          True              NaN       NaN                     NaN
#
#     trending_upwards  podcast_date
# 0                NaN           NaT
# 1                NaN           NaT
# 2                NaN           NaT
# 3                NaN           NaT
# 4                NaN           NaT
# 5                NaN           NaT
# 6                NaN           NaT
# 7                NaN           NaT
# 8                NaN           NaT
# 9                NaN           NaT
# 10               NaN           NaT
# 11               NaN           NaT
# 12               NaN           NaT
# 13               NaN           NaT
# 14               NaN           NaT
# 15               1.0    2023-10-27
# 16               NaN           NaT
# 17               NaN           NaT
# 18               NaN           NaT
# 19               NaN           NaT
# 20               NaN           NaT
# 21               NaN           NaT
# 22               NaN           NaT
# 23               NaN           NaT
# 24               0.0    2023-10-27
# 25               NaN           NaT
# 26               NaN           NaT
# 27               NaN           NaT
# 28               NaN           NaT
# 29               NaN           NaT
# 30               NaN           NaT
# 31               NaN           NaT
# 32               NaN           NaT
# 33               NaN           NaT
# 34               NaN           NaT
# 35               NaN           NaT
# 36               NaN           NaT
# 37               NaN           NaT
# 38               NaN           NaT
# 39               NaN           NaT
#
# [40 rows x 36 columns]

# %%
m[~m.player.isnull()]
# Out:
#      season_year  game_date    gameId      matchup   teamName   teamSlug  \
# 15       2023-24 2023-10-27  22300077    DET @ CHA    pistons    pistons
# 24       2023-24 2023-10-27  22300077  CHA vs. DET    hornets    hornets
# 44       2023-24 2023-10-27  22300078  MEM vs. DEN  grizzlies  grizzlies
# 131      2023-24 2023-10-27  22300081    OKC @ CLE    thunder    thunder
# 140      2023-24 2023-10-27  22300081    OKC @ CLE    thunder    thunder
# 150      2023-24 2023-10-27  22300082  CHI vs. TOR      bulls      bulls
# 224      2023-24 2023-10-27  22300084    BKN @ DAL       nets       nets
# 288      2023-24 2023-10-27  22300087    GSW @ SAC   warriors   warriors
# 318      2023-24 2023-10-28  22300088    CHI @ DET      bulls      bulls
# 331      2023-24 2023-10-28  22300088  DET vs. CHI    pistons    pistons
# 355      2023-24 2023-10-28  22300089    MEM @ WAS  grizzlies  grizzlies
# 433      2023-24 2023-10-28  22300092    PHI @ TOR      76ers     sixers
# 445      2023-24 2023-10-28  22300092    PHI @ TOR      76ers     sixers
# 490      2023-24 2023-10-28  22300094  PHX vs. UTA       suns       suns
# 519      2023-24 2023-10-29  22300095  OKC vs. DEN    thunder    thunder
# 525      2023-24 2023-10-29  22300095  OKC vs. DEN    thunder    thunder
# 535      2023-24 2023-10-29  22300096    GSW @ HOU   warriors   warriors
# 566      2023-24 2023-10-29  22300097  MIL vs. ATL      bucks      bucks
# 598      2023-24 2023-10-29  22300098  PHI vs. POR      76ers     sixers
# 609      2023-24 2023-10-29  22300098  PHI vs. POR      76ers     sixers
# 651      2023-24 2023-10-29  22300100    LAL @ SAC     lakers     lakers
# 694      2023-24 2023-10-30  22300101    BKN @ CHA       nets       nets
# 698      2023-24 2023-10-30  22300101  CHA vs. BKN    hornets    hornets
# 704      2023-24 2023-10-30  22300102    CHI @ IND      bulls      bulls
# 830      2023-24 2023-10-30  22300106  MEM vs. DAL  grizzlies  grizzlies
# 847      2023-24 2023-10-30  22300107  MIL vs. MIA      bucks      bucks
# 869      2023-24 2023-10-30  22300108    GSW @ NOP   warriors   warriors
# 906      2023-24 2023-10-30  22300109  OKC vs. DET    thunder    thunder
# 909      2023-24 2023-10-30  22300109    DET @ OKC    pistons    pistons
# 915      2023-24 2023-10-30  22300109  OKC vs. DET    thunder    thunder
# 952      2023-24 2023-10-30  22300111  LAL vs. ORL     lakers     lakers
# 1017     2023-24 2023-10-31  22300113  PHX vs. SAS       suns       suns
#
#       personId       personName    minutes  fieldGoalsMade  ...  points  \
# 15     1630595  cade cunningham  24.133333               4  ...      12
# 24     1641706   brandon miller  33.416667               6  ...      17
# 44     1630214   xavier tillman  34.050000               5  ...      13
# 131    1630198       isaiah joe  22.300000               2  ...       5
# 140    1631096    chet holmgren  30.850000               5  ...      16
# 150     203083   andre drummond  12.333333               3  ...       8
# 224    1630560       cam thomas  33.166667              12  ...      30
# 288     101108       chris paul  33.166667               5  ...      10
# 318     203083   andre drummond  14.466667               1  ...       2
# 331    1630595  cade cunningham  39.616667               9  ...      25
# 355    1630214   xavier tillman  23.733333               3  ...       8
# 433     203954      joel embiid  35.350000              14  ...      34
# 445    1630178     tyrese maxey  40.566667              12  ...      34
# 490    1629006      josh okogie  23.233333               2  ...       7
# 519    1630198       isaiah joe  16.700000               2  ...       5
# 525    1631096    chet holmgren  25.566667               7  ...      19
# 535     101108       chris paul  27.416667               3  ...       8
# 566     203081   damian lillard  29.033333               2  ...       6
# 598     203954      joel embiid  29.416667              12  ...      35
# 609    1630178     tyrese maxey  34.733333               6  ...      26
# 651     203076    anthony davis  41.683333              11  ...      30
# 694    1630560       cam thomas  38.000000              10  ...      33
# 698    1641706   brandon miller  36.116667               7  ...      22
# 704     203083   andre drummond  13.716667               2  ...       5
# 830    1630214   xavier tillman  28.866667               3  ...       6
# 847     203081   damian lillard  35.033333               7  ...      25
# 869     101108       chris paul  25.216667               6  ...      13
# 906    1630198       isaiah joe  19.600000               3  ...       9
# 909    1630595  cade cunningham  35.450000               5  ...      17
# 915    1631096    chet holmgren  24.033333               4  ...      14
# 952     203076    anthony davis  38.200000              12  ...      26
# 1017   1629006      josh okogie  30.066667               3  ...      11
#
#       plusMinusPoints  fantasyPoints  projectedFantasyPoints  outperformed  \
# 15                  7          23.00               33.700000         False
# 24                 -2          30.00               19.250000          True
# 44                 -5          33.50               19.150000          True
# 131                12          11.25               16.000000         False
# 140                 6          52.25               22.000000          True
# 150                 1           9.50               10.750000         False
# 224                 3          45.75               19.150000          True
# 288                 2          36.50               34.250000          True
# 318                -5          19.25               10.450000          True
# 331                10          43.50               33.400000          True
# 355               -14          20.75               22.550000         False
# 433                -2          62.75               48.950000          True
# 445                10          53.50               32.100000          True
# 490                25           8.25               25.050000         False
# 519                -5          16.50               16.400000          True
# 525               -23          23.50               37.125000         False
# 535                22          26.25               35.250000         False
# 566               -29          19.50               53.350000         False
# 598                28          80.25               53.000000          True
# 609                19          45.00               35.500000          True
# 651               -10          64.50               48.450000          True
# 694                 8          37.50               28.400000          True
# 698                -4          38.25               24.625000          True
# 704                 7          13.25               13.200000          True
# 830                 4          22.25               25.500000         False
# 847                 2          37.25               46.200000         False
# 869                17          31.50               34.050000         False
# 906                 2           8.50               14.850000         False
# 909               -14          23.50               34.850000         False
# 915                 9          34.00               32.583333          True
# 952                -2          66.25               52.900000          True
# 1017               -3          19.50               23.250000         False
#
#                player  mentions  increased_playing_time  trending_upwards  \
# 15    cade cunningham       2.0                     1.0               1.0
# 24     brandon miller       1.0                     0.0               0.0
# 44     xavier tillman       3.0                     1.0               1.0
# 131        isaiah joe       2.0                     1.0               1.0
# 140     chet holmgren       4.0                     0.0               0.0
# 150    andre drummond       2.0                     1.0               1.0
# 224        cam thomas       4.0                     1.0               1.0
# 288        chris paul       2.0                     1.0               1.0
# 318    andre drummond       2.0                     1.0               1.0
# 331   cade cunningham       2.0                     1.0               1.0
# 355    xavier tillman       3.0                     1.0               1.0
# 433       joel embiid       4.0                     0.0               0.0
# 445      tyrese maxey       1.0                     1.0               1.0
# 490       josh okogie       1.0                     1.0               1.0
# 519        isaiah joe       2.0                     1.0               1.0
# 525     chet holmgren       4.0                     0.0               0.0
# 535        chris paul       2.0                     1.0               1.0
# 566    damian lillard       3.0                     0.0               1.0
# 598       joel embiid       4.0                     0.0               0.0
# 609      tyrese maxey       1.0                     1.0               1.0
# 651     anthony davis       3.0                     1.0               1.0
# 694        cam thomas       4.0                     1.0               1.0
# 698    brandon miller       1.0                     0.0               0.0
# 704    andre drummond       2.0                     1.0               1.0
# 830    xavier tillman       3.0                     1.0               1.0
# 847    damian lillard       3.0                     0.0               1.0
# 869        chris paul       2.0                     1.0               1.0
# 906        isaiah joe       2.0                     1.0               1.0
# 909   cade cunningham       2.0                     1.0               1.0
# 915     chet holmgren       4.0                     0.0               0.0
# 952     anthony davis       3.0                     1.0               1.0
# 1017      josh okogie       1.0                     1.0               1.0
#
#       podcast_date
# 15      2023-10-27
# 24      2023-10-27
# 44      2023-10-27
# 131     2023-10-27
# 140     2023-10-27
# 150     2023-10-27
# 224     2023-10-27
# 288     2023-10-27
# 318     2023-10-27
# 331     2023-10-27
# 355     2023-10-27
# 433     2023-10-27
# 445     2023-10-27
# 490     2023-10-27
# 519     2023-10-27
# 525     2023-10-27
# 535     2023-10-27
# 566     2023-10-27
# 598     2023-10-27
# 609     2023-10-27
# 651     2023-10-27
# 694     2023-10-27
# 698     2023-10-27
# 704     2023-10-27
# 830     2023-10-27
# 847     2023-10-27
# 869     2023-10-27
# 906     2023-10-27
# 909     2023-10-27
# 915     2023-10-27
# 952     2023-10-27
# 1017    2023-10-27
#
# [32 rows x 36 columns]

# %%
# Out:
# {'andre drummond',
#  'brandon miller',
#  'cade cunningham',
#  'cam thomas',
#  'chet holmgren',
#  'chris paul',
#  'isaiah joe',
#  'xavier tillman'}

# %%
# Out:
#                                                player   mentions  \
# 0                                      Damian Lillard        3.0
# 1                                        Tyrese Maxey        1.0
# 2                                         Kelly Oubre        1.0
# 3                                        James Harden        6.0
# 4                                         Joel Embiid        3.0
# 5                                       Terrence Mann        1.0
# 6                                         Norm Powell        1.0
# 7                                        Bones Hyland        1.0
# 8                                       Anthony Davis        1.0
# 9                                        Miles Turner        2.0
# 10                                     Brandon Miller        2.0
# 11                                     Xavier Tillman        3.0
# 12                                       Santi Aldama        1.0
# 13                                         Kobe White        1.0
# 14                                       Derek Lively        3.0
# 15                                         Cam Thomas        3.0
# 16                                         Isaiah Joe        1.0
# 17                                        Josh Okogie        1.0
# 18                                         Chris Paul        1.0
# 19                                    Cade Cunningham        2.0
# 20                                        Jalen Duran        2.0
# 21                                     Andre Drummond        2.0
# 22                                  Victor Wembanyama        1.0
# 23                                      Chet Holmgren        4.0
# 24                                     George Muresan        1.0
# 25                          John "Hot Plate" Williams        1.0
# 26                 Darryl "Chocolate Thunder" Dawkins        1.0
# 27                                        Jeff Ruland        1.0
# 28                                        Rick Mahorn        1.0
# 29                           Mel "Dinner Bell" Turpin        1.0
# 30  Note: The analysis is based on the text provid...        NaN
#
#     increased_playing_time  trending_upwards
# 0                       no               yes
# 1                      yes               yes
# 2                       no                no
# 3                       no                no
# 4                       no                no
# 5                       no                no
# 6                       no                no
# 7                       no                no
# 8                       no                no
# 9                       no                no
# 10                      no                no
# 11                     yes               yes
# 12                     yes               yes
# 13                     yes               yes
# 14                     yes               yes
# 15                     yes               yes
# 16                     yes               yes
# 17                     yes               yes
# 18                     yes               yes
# 19                      no                no
# 20                      no                no
# 21                      no                no
# 22                      no                no
# 23                      no                no
# 24                      no                no
# 25                      no                no
# 26                      no                no
# 27                      no                no
# 28                      no                no
# 29                      no                no
# 30                     NaN               NaN

# %%
import spacy

# Load SpaCy English model
nlp = spacy.load("en_core_web_lg")

# Process the text with SpaCy
doc = nlp(podcast_text)

target = "James Harden"
# Count mentions of "James Harden"
count = sum(1 for ent in doc.ents if ent.text == target and ent.label_ == "PERSON")
count
# Out:
# 2

# %%
-----

# %%
prompt = podcast_text

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": prompt},
]

from langchain_google_vertexai import ChatVertexAI

llm = ChatVertexAI(model="gemini-1.5-flash", temperature=0)
response = llm.invoke(messages)

print("Response:", response.content)

# %%
response.content
# Out:
# "```csv\nPlayer,Mentions,Increased Playing Time,Trending Upwards\nDamian Lillard,4,No,No\nJames Harden,6,No,No\nTyrese Maxey,1,Yes,Yes\nKelly Oubre,1,No,No\nJoel Embiid,2,No,No\nTerrence Mann,1,No,No\nNorm Powell,1,No,No\nBones Hyland,1,No,No\nBogdanovic,1,No,No\nAnthony Davis,2,No,No\nLeBron James,1,No,No\nKevin Durant,2,No,No\nYousef Nurkic,1,No,No\nEric Gordon,3,Yes,No\nJordan Goodwin,1,Yes,Yes\nJay Eric Gordon,1,No,No\nBradley Beal,3,No,No\nMiles Turner,2,No,No\nBrandon Miller,2,No,No\nXavier Tillman,3,Yes,Yes\nSanti Aldama,2,Yes,Yes\nJaren Jackson,1,No,No\nJa Morant,1,No,No\nKobe White,3,Yes,Yes\nDerek Lively,4,Yes,Yes\nMaxi Kleber,1,No,No\nKyrie Irving,1,No,No\nJason Kidd,1,No,No\nJalen Johnson,4,Yes,Yes\nSadik Bey,3,No,No\nDeandre Hunter,2,No,No\nDonovic Mitchell,1,No,No\nAJ Griffin,2,No,No\nCam Thomas,6,Yes,Yes\nRoyce O'Neil,1,No,No\nDorian Finney Smith,1,No,No\nBen Simmons,2,No,No\nNick Claxton,2,No,No\nCam Johnson,2,No,No\nSpencer Dinwiddie,1,No,No\nMax Struss,5,Yes,Yes\nJared Allen,1,No,No\nIsaac Okoro,1,No,No\nCaris LeVert,2,No,No\nIsaiah Joe,2,Yes,Yes\nTrey Murphy,2,No,No\nHerb Jones,2,No,No\nJosh Okogi,3,Yes,Yes\nGrayson Allen,1,No,No\nDraymond Green,2,No,No\nChris Paul,2,Yes,Yes\nKyle Lowry,1,No,No\nVictor Wembanyama,2,Yes,Yes\nChet Holmgren,4,Yes,Yes\nAndre Drummond,2,No,No\nCade Cunningham,2,Yes,Yes\nJalen Duren,2,Yes,Yes\nBojan Bogdanovic,1,No,No\nMonty Morris,1,No,No\nBam Adebayo,1,No,No\nJaylen Brown,1,No,No\nEvan Mobley,2,No,No\nJalen Williams,1,No,No\nDejounte Murray,1,No,No\nMarkelle Fultz,2,Yes,Yes\nJayson Tatum,1,No,No\nRobert Williams,1,No,No\nLuka Doncic,1,No,No\n```"

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

prompt = "What is the capital of France?"

messages = [
    {
        "role": "system",
        "content": "You are a helpful assistant that answers questions.",
    },
    {"role": "user", "content": prompt},
]
response = llm.invoke(prompt)
response.content
# Out:
# 'The capital of France is Paris.'

# %%
from langchain_google_vertexai import ChatVertexAI

llm = ChatVertexAI(model="gemini-1.5-flash", temperature=0)


prompt = "What is the capital of France?"

messages = [
    {
        "role": "system",
        "content": "You are a helpful assistant that answers questions.",
    },
    {"role": "user", "content": prompt},
]


response = llm.invoke(messages)


print("Response:", response.content)
# Out:
# Response: The capital of France is **Paris**.
